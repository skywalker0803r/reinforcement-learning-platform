# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.distributions import Categorical
from torch import optim
from torch import nn
from collections import deque
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd
import warnings;warnings.simplefilter('ignore')

seed = 6
torch.manual_seed(seed)

# %% [markdown]
# # models

# %%
class critic(nn.Module):
    def __init__(self, input_dim):
        super(critic, self).__init__()
        self.fc1 = nn.Linear(input_dim,128)
        self.fc2 = nn.Linear(128,64)
        self.fc3 = nn.Linear(64,1)

    def forward(self,state):
        state = F.relu(self.fc1(state))
        state = F.relu(self.fc2(state))
        return self.fc3(state)

# %%
class actor(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(actor, self).__init__()
        self.fc1 = nn.Linear(input_dim,128)
        self.fc2 = nn.Linear(128,64)
        self.fc3 = nn.Linear(64,output_dim)
    
    def forward(self, state):
        logits = F.relu(self.fc1(state))
        logits = F.relu(self.fc2(logits))
        return F.softmax(self.fc3(logits),dim = -1)

# %% [markdown]
# # agent

# %%
class A2CAgent:
    def __init__(self,env,gamma = 0.99 ,lr = 1e-3):
        
        # common paramters
        self.device = "cuda"
        self.env = env
        self.obs_dim = env.observation_space.shape[0]
        self.action_dim = env.action_space.n
        self.best_score = -np.inf
        
        # Hyper paramters
        self.gamma = gamma
        self.lr = lr
        
        # critic_net
        self.critic = critic(self.obs_dim).to(self.device)
        self.critic.apply(self._weights_init)
        
        # actor_net
        self.actor = actor(self.obs_dim,self.action_dim).to(self.device)
        self.actor.apply(self._weights_init)
        
        # optimizers
        self.critic_optimizer = optim.Adam(self.critic.parameters(),lr=lr)
        self.actor_optimizer = optim.Adam(self.actor.parameters(),lr=lr)
            
    @staticmethod
    def _weights_init(m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            nn.init.constant_(m.bias,0.01)
    
    def get_action(self,state):
        state = torch.FloatTensor([state]).to(self.device)
        probs = self.actor(state) # softmax probs
        dist = Categorical(probs) # Categorical distribution
        act = dist.sample() # smaple action from this Categorical distribution
        return act.detach().item()
    
    def get_value(self,state):
        state = torch.FloatTensor([state]).to(self.device)
        value = self.critic(state)
        return value.item()
    
    def compute_returns(self,rewards):
        returns = []
        G = 0
        
        for r in rewards[::-1]:
            G = r + self.gamma*G
            returns.insert(0,G)
        
        returns = np.array([i for i in returns]).ravel()
        return torch.FloatTensor(returns).to(self.device).view(-1, 1)
    
    def normalize(self,x):
        return (x - x.mean()) / x.std()
    
    def update(self,trajectory):
        
        print('update...')
        
        # get trajectory
        state = torch.FloatTensor([sars[0] for sars in trajectory]).to(self.device)
        action = torch.LongTensor([sars[1] for sars in trajectory]).to(self.device).view(-1, 1)
        rewards = [sars[2] for sars in trajectory]
        next_state = torch.FloatTensor([sars[3] for sars in trajectory]).to(self.device)
        done = torch.FloatTensor([sars[4] for sars in trajectory]).to(self.device).view(-1, 1)  
            
        # calculate critic loss
        values = self.critic(state)
        returns = self.compute_returns(rewards)
        advantage = returns.detach() - values
        critic_loss = advantage**2
            
        # calculate actor_loss
        logp = torch.gather(self.actor(state),1,action).log()
        actor_loss = -logp * advantage.detach()
            
        # update critic
        self.critic_optimizer.zero_grad()
        critic_loss.mean().backward()
        self.critic_optimizer.step()
            
        # update actor
        self.actor_optimizer.zero_grad()
        actor_loss.mean().backward()
        self.actor_optimizer.step()
    
    def train(self,max_episodes):
        episode_rewards = []
        
        for episode in range(max_episodes):
            
            # initialize new game
            state = env.reset()
            trajectory = []
            episode_reward = 0
            done = False
            
            # game loop
            while not done:
                action = self.get_action(state)
                next_state, reward, done, _ = self.env.step(action)
                trajectory.append([state, action, reward, next_state, done])
                episode_reward += reward
                state = next_state
            
            # game over
            episode_rewards.append(episode_reward)
            self.best_score = max(self.best_score,episode_reward)
            print("Episode {} reward {} best {}".format(episode,episode_reward,self.best_score))
            if episode_reward < self.best_score:
                self.update(trajectory)
        
        return episode_rewards
    
    def play(self,max_episodes):
        episode_rewards = []
        
        for episode in range(max_episodes):
            
            # initialize new game
            state = env.reset()
            episode_reward = 0
            done = False
            
            # game loop
            while not done:
                self.env.render()
                action = self.get_action(state)
                next_state, reward, done, _ = self.env.step(action)
                episode_reward += reward
                state = next_state
            
            # game over
            print("Episode " + str(episode) + ": " + str(episode_reward))
            episode_rewards.append(episode_reward)
        
        return episode_rewards

# %%
import gym

env = gym.make("CartPole-v1")
env.seed(seed)

agent = A2CAgent(env)

history = agent.train(max_episodes=300)
# Out:
# Episode 0 reward 26.0 best 26.0
# Episode 1 reward 21.0 best 26.0
# update...
# Episode 2 reward 12.0 best 26.0
# update...
# Episode 3 reward 14.0 best 26.0
# update...
# Episode 4 reward 17.0 best 26.0
# update...
# Episode 5 reward 14.0 best 26.0
# update...
# Episode 6 reward 13.0 best 26.0
# update...
# Episode 7 reward 19.0 best 26.0
# update...
# Episode 8 reward 21.0 best 26.0
# update...
# Episode 9 reward 16.0 best 26.0
# update...
# Episode 10 reward 17.0 best 26.0
# update...
# Episode 11 reward 15.0 best 26.0
# update...
# Episode 12 reward 14.0 best 26.0
# update...
# Episode 13 reward 14.0 best 26.0
# update...
# Episode 14 reward 19.0 best 26.0
# update...
# Episode 15 reward 43.0 best 43.0
# Episode 16 reward 14.0 best 43.0
# update...
# Episode 17 reward 17.0 best 43.0
# update...
# Episode 18 reward 14.0 best 43.0
# update...
# Episode 19 reward 31.0 best 43.0
# update...
# Episode 20 reward 23.0 best 43.0
# update...
# Episode 21 reward 30.0 best 43.0
# update...
# Episode 22 reward 12.0 best 43.0
# update...
# Episode 23 reward 18.0 best 43.0
# update...
# Episode 24 reward 52.0 best 52.0
# Episode 25 reward 21.0 best 52.0
# update...
# Episode 26 reward 29.0 best 52.0
# update...
# Episode 27 reward 37.0 best 52.0
# update...
# Episode 28 reward 19.0 best 52.0
# update...
# Episode 29 reward 13.0 best 52.0
# update...
# Episode 30 reward 32.0 best 52.0
# update...
# Episode 31 reward 19.0 best 52.0
# update...
# Episode 32 reward 19.0 best 52.0
# update...
# Episode 33 reward 16.0 best 52.0
# update...
# Episode 34 reward 17.0 best 52.0
# update...
# Episode 35 reward 17.0 best 52.0
# update...
# Episode 36 reward 42.0 best 52.0
# update...
# Episode 37 reward 15.0 best 52.0
# update...
# Episode 38 reward 13.0 best 52.0
# update...
# Episode 39 reward 13.0 best 52.0
# update...
# Episode 40 reward 15.0 best 52.0
# update...
# Episode 41 reward 58.0 best 58.0
# Episode 42 reward 14.0 best 58.0
# update...
# Episode 43 reward 14.0 best 58.0
# update...
# Episode 44 reward 31.0 best 58.0
# update...
# Episode 45 reward 16.0 best 58.0
# update...
# Episode 46 reward 15.0 best 58.0
# update...
# Episode 47 reward 22.0 best 58.0
# update...
# Episode 48 reward 29.0 best 58.0
# update...
# Episode 49 reward 36.0 best 58.0
# update...
# Episode 50 reward 21.0 best 58.0
# update...
# Episode 51 reward 21.0 best 58.0
# update...
# Episode 52 reward 63.0 best 63.0
# Episode 53 reward 12.0 best 63.0
# update...
# Episode 54 reward 18.0 best 63.0
# update...
# Episode 55 reward 28.0 best 63.0
# update...
# Episode 56 reward 19.0 best 63.0
# update...
# Episode 57 reward 33.0 best 63.0
# update...
# Episode 58 reward 13.0 best 63.0
# update...
# Episode 59 reward 32.0 best 63.0
# update...
# Episode 60 reward 24.0 best 63.0
# update...
# Episode 61 reward 28.0 best 63.0
# update...
# Episode 62 reward 41.0 best 63.0
# update...
# Episode 63 reward 30.0 best 63.0
# update...
# Episode 64 reward 47.0 best 63.0
# update...
# Episode 65 reward 23.0 best 63.0
# update...
# Episode 66 reward 15.0 best 63.0
# update...
# Episode 67 reward 15.0 best 63.0
# update...
# Episode 68 reward 22.0 best 63.0
# update...
# Episode 69 reward 13.0 best 63.0
# update...
# Episode 70 reward 17.0 best 63.0
# update...
# Episode 71 reward 18.0 best 63.0
# update...
# Episode 72 reward 9.0 best 63.0
# update...
# Episode 73 reward 25.0 best 63.0
# update...
# Episode 74 reward 17.0 best 63.0
# update...
# Episode 75 reward 20.0 best 63.0
# update...
# Episode 76 reward 58.0 best 63.0
# update...
# Episode 77 reward 17.0 best 63.0
# update...
# Episode 78 reward 32.0 best 63.0
# update...
# Episode 79 reward 18.0 best 63.0
# update...
# Episode 80 reward 20.0 best 63.0
# update...
# Episode 81 reward 43.0 best 63.0
# update...
# Episode 82 reward 14.0 best 63.0
# update...
# Episode 83 reward 20.0 best 63.0
# update...
# Episode 84 reward 43.0 best 63.0
# update...
# Episode 85 reward 10.0 best 63.0
# update...
# Episode 86 reward 43.0 best 63.0
# update...
# Episode 87 reward 17.0 best 63.0
# update...
# Episode 88 reward 30.0 best 63.0
# update...
# Episode 89 reward 29.0 best 63.0
# update...
# Episode 90 reward 25.0 best 63.0
# update...
# Episode 91 reward 17.0 best 63.0
# update...
# Episode 92 reward 37.0 best 63.0
# update...
# Episode 93 reward 24.0 best 63.0
# update...
# Episode 94 reward 19.0 best 63.0
# update...
# Episode 95 reward 28.0 best 63.0
# update...
# Episode 96 reward 49.0 best 63.0
# update...
# Episode 97 reward 16.0 best 63.0
# update...
# Episode 98 reward 16.0 best 63.0
# update...
# Episode 99 reward 88.0 best 88.0
# Episode 100 reward 15.0 best 88.0
# update...
# Episode 101 reward 70.0 best 88.0
# update...
# Episode 102 reward 49.0 best 88.0
# update...
# Episode 103 reward 32.0 best 88.0
# update...
# Episode 104 reward 21.0 best 88.0
# update...
# Episode 105 reward 23.0 best 88.0
# update...
# Episode 106 reward 25.0 best 88.0
# update...
# Episode 107 reward 35.0 best 88.0
# update...
# Episode 108 reward 22.0 best 88.0
# update...
# Episode 109 reward 53.0 best 88.0
# update...
# Episode 110 reward 31.0 best 88.0
# update...
# Episode 111 reward 25.0 best 88.0
# update...
# Episode 112 reward 36.0 best 88.0
# update...
# Episode 113 reward 33.0 best 88.0
# update...
# Episode 114 reward 38.0 best 88.0
# update...
# Episode 115 reward 44.0 best 88.0
# update...
# Episode 116 reward 14.0 best 88.0
# update...
# Episode 117 reward 42.0 best 88.0
# update...
# Episode 118 reward 69.0 best 88.0
# update...
# Episode 119 reward 48.0 best 88.0
# update...
# Episode 120 reward 36.0 best 88.0
# update...
# Episode 121 reward 35.0 best 88.0
# update...
# Episode 122 reward 55.0 best 88.0
# update...
# Episode 123 reward 112.0 best 112.0
# Episode 124 reward 54.0 best 112.0
# update...
# Episode 125 reward 28.0 best 112.0
# update...
# Episode 126 reward 98.0 best 112.0
# update...
# Episode 127 reward 86.0 best 112.0
# update...
# Episode 128 reward 39.0 best 112.0
# update...
# Episode 129 reward 26.0 best 112.0
# update...
# Episode 130 reward 53.0 best 112.0
# update...
# Episode 131 reward 38.0 best 112.0
# update...
# Episode 132 reward 55.0 best 112.0
# update...
# Episode 133 reward 44.0 best 112.0
# update...
# Episode 134 reward 50.0 best 112.0
# update...
# Episode 135 reward 121.0 best 121.0
# Episode 136 reward 33.0 best 121.0
# update...
# Episode 137 reward 37.0 best 121.0
# update...
# Episode 138 reward 70.0 best 121.0
# update...
# Episode 139 reward 66.0 best 121.0
# update...
# Episode 140 reward 60.0 best 121.0
# update...
# Episode 141 reward 102.0 best 121.0
# update...
# Episode 142 reward 62.0 best 121.0
# update...
# Episode 143 reward 231.0 best 231.0
# Episode 144 reward 29.0 best 231.0
# update...
# Episode 145 reward 32.0 best 231.0
# update...
# Episode 146 reward 46.0 best 231.0
# update...
# Episode 147 reward 74.0 best 231.0
# update...
# Episode 148 reward 134.0 best 231.0
# update...
# Episode 149 reward 68.0 best 231.0
# update...
# Episode 150 reward 33.0 best 231.0
# update...
# Episode 151 reward 49.0 best 231.0
# update...
# Episode 152 reward 156.0 best 231.0
# update...
# Episode 153 reward 87.0 best 231.0
# update...
# Episode 154 reward 270.0 best 270.0
# Episode 155 reward 42.0 best 270.0
# update...
# Episode 156 reward 128.0 best 270.0
# update...
# Episode 157 reward 67.0 best 270.0
# update...
# Episode 158 reward 97.0 best 270.0
# update...
# Episode 159 reward 242.0 best 270.0
# update...
# Episode 160 reward 162.0 best 270.0
# update...
# Episode 161 reward 150.0 best 270.0
# update...
# Episode 162 reward 136.0 best 270.0
# update...
# Episode 163 reward 279.0 best 279.0
# Episode 164 reward 239.0 best 279.0
# update...
# Episode 165 reward 109.0 best 279.0
# update...
# Episode 166 reward 88.0 best 279.0
# update...
# Episode 167 reward 140.0 best 279.0
# update...
# Episode 168 reward 197.0 best 279.0
# update...
# Episode 169 reward 221.0 best 279.0
# update...
# Episode 170 reward 52.0 best 279.0
# update...
# Episode 171 reward 116.0 best 279.0
# update...
# Episode 172 reward 85.0 best 279.0
# update...
# Episode 173 reward 172.0 best 279.0
# update...
# Episode 174 reward 144.0 best 279.0
# update...
# Episode 175 reward 212.0 best 279.0
# update...
# Episode 176 reward 263.0 best 279.0
# update...
# Episode 177 reward 120.0 best 279.0
# update...
# Episode 178 reward 240.0 best 279.0
# update...
# Episode 179 reward 78.0 best 279.0
# update...
# Episode 180 reward 227.0 best 279.0
# update...
# Episode 181 reward 500.0 best 500.0
# Episode 182 reward 430.0 best 500.0
# update...
# Episode 183 reward 220.0 best 500.0
# update...
# Episode 184 reward 267.0 best 500.0
# update...
# Episode 185 reward 173.0 best 500.0
# update...
# Episode 186 reward 183.0 best 500.0
# update...
# Episode 187 reward 227.0 best 500.0
# update...
# Episode 188 reward 173.0 best 500.0
# update...
# Episode 189 reward 269.0 best 500.0
# update...
# Episode 190 reward 159.0 best 500.0
# update...
# Episode 191 reward 54.0 best 500.0
# update...
# Episode 192 reward 149.0 best 500.0
# update...
# Episode 193 reward 170.0 best 500.0
# update...
# Episode 194 reward 140.0 best 500.0
# update...
# Episode 195 reward 180.0 best 500.0
# update...
# Episode 196 reward 138.0 best 500.0
# update...
# Episode 197 reward 173.0 best 500.0
# update...
# Episode 198 reward 209.0 best 500.0
# update...
# Episode 199 reward 187.0 best 500.0
# update...
# Episode 200 reward 195.0 best 500.0
# update...
# Episode 201 reward 192.0 best 500.0
# update...
# Episode 202 reward 154.0 best 500.0
# update...
# Episode 203 reward 198.0 best 500.0
# update...
# Episode 204 reward 149.0 best 500.0
# update...
# Episode 205 reward 166.0 best 500.0
# update...
# Episode 206 reward 191.0 best 500.0
# update...
# Episode 207 reward 126.0 best 500.0
# update...
# Episode 208 reward 137.0 best 500.0
# update...
# Episode 209 reward 217.0 best 500.0
# update...
# Episode 210 reward 188.0 best 500.0
# update...
# Episode 211 reward 142.0 best 500.0
# update...
# Episode 212 reward 231.0 best 500.0
# update...
# Episode 213 reward 196.0 best 500.0
# update...
# Episode 214 reward 376.0 best 500.0
# update...
# Episode 215 reward 235.0 best 500.0
# update...
# Episode 216 reward 500.0 best 500.0
# Episode 217 reward 394.0 best 500.0
# update...
# Episode 218 reward 446.0 best 500.0
# update...
# Episode 219 reward 500.0 best 500.0
# Episode 220 reward 500.0 best 500.0
# Episode 221 reward 500.0 best 500.0
# Episode 222 reward 500.0 best 500.0
# Episode 223 reward 500.0 best 500.0
# Episode 224 reward 336.0 best 500.0
# update...
# Episode 225 reward 500.0 best 500.0
# Episode 226 reward 500.0 best 500.0
# Episode 227 reward 500.0 best 500.0
# Episode 228 reward 500.0 best 500.0
# Episode 229 reward 500.0 best 500.0
# Episode 230 reward 500.0 best 500.0
# Episode 231 reward 245.0 best 500.0
# update...
# Episode 232 reward 500.0 best 500.0
# Episode 233 reward 28.0 best 500.0
# update...
# Episode 234 reward 500.0 best 500.0
# Episode 235 reward 491.0 best 500.0
# update...
# Episode 236 reward 340.0 best 500.0
# update...
# Episode 237 reward 435.0 best 500.0
# update...
# Episode 238 reward 500.0 best 500.0
# Episode 239 reward 500.0 best 500.0
# Episode 240 reward 500.0 best 500.0
# Episode 241 reward 500.0 best 500.0
# Episode 242 reward 500.0 best 500.0
# Episode 243 reward 500.0 best 500.0
# Episode 244 reward 500.0 best 500.0
# Episode 245 reward 300.0 best 500.0
# update...
# Episode 246 reward 98.0 best 500.0
# update...
# Episode 247 reward 500.0 best 500.0
# Episode 248 reward 424.0 best 500.0
# update...
# Episode 249 reward 500.0 best 500.0
# Episode 250 reward 232.0 best 500.0
# update...
# Episode 251 reward 500.0 best 500.0
# Episode 252 reward 384.0 best 500.0
# update...
# Episode 253 reward 401.0 best 500.0
# update...
# Episode 254 reward 500.0 best 500.0
# Episode 255 reward 500.0 best 500.0
# Episode 256 reward 500.0 best 500.0
# Episode 257 reward 500.0 best 500.0
# Episode 258 reward 500.0 best 500.0
# Episode 259 reward 500.0 best 500.0
# Episode 260 reward 500.0 best 500.0
# Episode 261 reward 500.0 best 500.0
# Episode 262 reward 500.0 best 500.0
# Episode 263 reward 500.0 best 500.0
# Episode 264 reward 500.0 best 500.0
# Episode 265 reward 500.0 best 500.0
# Episode 266 reward 500.0 best 500.0
# Episode 267 reward 500.0 best 500.0
# Episode 268 reward 277.0 best 500.0
# update...
# Episode 269 reward 500.0 best 500.0
# Episode 270 reward 500.0 best 500.0
# Episode 271 reward 500.0 best 500.0
# Episode 272 reward 500.0 best 500.0
# Episode 273 reward 500.0 best 500.0
# Episode 274 reward 181.0 best 500.0
# update...
# Episode 275 reward 500.0 best 500.0
# Episode 276 reward 500.0 best 500.0
# Episode 277 reward 500.0 best 500.0
# Episode 278 reward 500.0 best 500.0
# Episode 279 reward 500.0 best 500.0
# Episode 280 reward 500.0 best 500.0
# Episode 281 reward 500.0 best 500.0
# Episode 282 reward 188.0 best 500.0
# update...
# Episode 283 reward 500.0 best 500.0
# Episode 284 reward 500.0 best 500.0
# Episode 285 reward 500.0 best 500.0
# Episode 286 reward 500.0 best 500.0
# Episode 287 reward 500.0 best 500.0
# Episode 288 reward 483.0 best 500.0
# update...
# Episode 289 reward 500.0 best 500.0
# Episode 290 reward 500.0 best 500.0
# Episode 291 reward 500.0 best 500.0
# Episode 292 reward 500.0 best 500.0
# Episode 293 reward 500.0 best 500.0
# Episode 294 reward 500.0 best 500.0
# Episode 295 reward 500.0 best 500.0
# Episode 296 reward 500.0 best 500.0
# Episode 297 reward 500.0 best 500.0
# Episode 298 reward 266.0 best 500.0
# update...
# Episode 299 reward 500.0 best 500.0

# %%
plt.plot(history)
plt.plot(pd.Series(history).rolling(10).mean())

# %% [markdown]
# # test

# %%
history = agent.play(max_episodes=10)
# Out:
# Episode 0: 500.0
# Episode 1: 353.0
# Episode 2: 247.0
# Episode 3: 500.0
# Episode 4: 500.0
# Episode 5: 500.0
# Episode 6: 500.0
# Episode 7: 370.0
# Episode 8: 500.0
# Episode 9: 500.0

# %%
agent.env.close()
