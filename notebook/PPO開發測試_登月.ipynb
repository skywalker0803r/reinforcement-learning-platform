# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.distributions import Categorical
from torch import optim
from torch import nn
from collections import deque
import numpy as np
import random
import warnings 
warnings.simplefilter('ignore')
seed = 6
torch.manual_seed(seed)

# %% [markdown]
# # model

# %%
class critic(nn.Module):
    def __init__(self, input_dim):
        # state -> value(type:scalar)
        super(critic, self).__init__()
        self.fc1 = nn.Linear(input_dim,128)
        self.fc2 = nn.Linear(128,128)
        self.fc3 = nn.Linear(128,1)

    def forward(self,state):
        state = F.relu(self.fc1(state))
        state = F.relu(self.fc2(state))
        value = self.fc3(state)
        return value

class actor(nn.Module):
    def __init__(self, input_dim, output_dim):
        # state -> action_probs(type:vector,sum==1)
        super(actor, self).__init__()
        self.fc1 = nn.Linear(input_dim,128)
        self.fc2 = nn.Linear(128,128)
        self.fc3 = nn.Linear(128,output_dim)
    
    def forward(self, state):
        logits = F.relu(self.fc1(state))
        logits = F.relu(self.fc2(logits))
        logits = self.fc3(logits)
        return F.softmax(logits,dim=1)

# %% [markdown]
# # utils

# %%
class BasicBuffer:
    def __init__(self, max_size):
        self.max_size = int(max_size)
        self.buffer = deque(maxlen=int(max_size))
    
    def clear(self):
        self.__init__(self.max_size)
        assert self.__len__() == 0

    def push(self, state, action, reward, next_state, done):
        experience = (state, action, np.array([reward]), next_state, done)
        self.buffer.append(experience)

    def sample(self, batch_size):
        state_batch = []
        action_batch = []
        reward_batch = []
        next_state_batch = []
        done_batch = []

        batch = random.sample(self.buffer, batch_size)

        for experience in batch:
            state, action, reward, next_state, done = experience
            state_batch.append(state)
            action_batch.append(action)
            reward_batch.append(reward)
            next_state_batch.append(next_state)
            done_batch.append(done)

        return (state_batch, action_batch, reward_batch, next_state_batch, done_batch)

    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# # agent

# %%
class PPOAgent:
    def __init__(self,env,gamma=1,lr=1e-2,clip=0.2,
                 v_coef=1,e_coef=0,eps=1e-12,K_epoch=100,buffer_maxsize=10000):
        self.device = "cuda"
        
        # env
        self.env = env
        self.obs_dim = env.observation_space.shape[0]
        self.action_dim = env.action_space.n
        
        # Hyperparamters
        self.gamma = gamma
        self.lr = lr
        self.clip = clip
        self.v_coef = v_coef
        self.e_coef = e_coef
        self.eps = eps
        self.K_epoch = K_epoch
        
        # critic,init
        self.critic = critic(self.obs_dim).to(self.device)
        self.critic.apply(self._weights_init)
        
        # actor_new,init
        self.actor_new = actor(self.obs_dim,self.action_dim).to(self.device)
        self.actor_new.apply(self._weights_init)
        
        # actor_old,sync
        self.actor_old = actor(self.obs_dim,self.action_dim).to(self.device)
        self.sync()
        
        # optimizer
        self.actor_optimizer = optim.Adam(self.actor_new.parameters(),lr=lr)
        self.critic_optimizer = optim.Adam(self.critic.parameters(),lr=lr)
        
        # replay buffer
        self.replay_buffer = BasicBuffer(max_size=buffer_maxsize)
        
        # recorder
        self.recorder = {'a_loss':[],
                         'v_loss':[],
                         'e_loss':[],
                         'ratio':[]}
            
    @staticmethod
    def _weights_init(m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            nn.init.constant_(m.bias, 0.1)
    
    def sync(self):
        for old_param, new_param in zip(self.actor_old.parameters(),self.actor_new.parameters()):
            old_param.data.copy_(new_param.data)

    def get_action(self, state):
        state = torch.FloatTensor(state).to(self.device)
        probs = self.actor_new.forward(state) # softmax_probs
        dist = Categorical(probs) # Categorical distribution
        act = dist.sample() # smaple action from this Categorical distribution
        return act.detach().item()

    def get_value(state):
        state = torch.FloatTensor(state).to(self.device)
        value = self.critic(state)
        return value.item()

    def update(self,batch_size=1024):
        for k in range(self.K_epoch):
            
            # sample mini_batch_data from replay_buffer
            s,a,r,s_,d = self.replay_buffer.sample(batch_size)
            s = torch.FloatTensor(s).to(self.device)
            a = torch.LongTensor(a).to(self.device).unsqueeze(dim=1)
            r = torch.FloatTensor(r).to(self.device)
            s_ = torch.FloatTensor(s_).to(self.device)
            d = torch.FloatTensor(d).to(self.device).unsqueeze(dim=1)
            
            # calculate critic loss
            v_target = r + self.gamma*self.critic(s_)*(1-d)
            v_current = self.critic(s)
            adv =  v_target - v_current
            v_loss = (adv**2).mean() * self.v_coef
            self.recorder['v_loss'].append(v_loss.item())
            
            # calculate ratio(new/old)
            new_p = torch.gather(self.actor_new(s),1,a)
            old_p = torch.gather(self.actor_old(s),1,a)
            ratio = new_p / (old_p + self.eps)
            self.recorder['ratio'].append(ratio.detach().cpu().numpy())
            
            # calculate entropy_loss
            distribution = Categorical(self.actor_new(s))
            entropy_loss = -distribution.entropy().mean() * self.e_coef
            self.recorder['e_loss'].append(entropy_loss.item())
            
            # calculate surr1,surr2
            adv = (adv - adv.mean()) / (adv.std() + self.eps)
            surr1 = ratio * adv.detach()
            surr2 = torch.clamp(ratio,1-self.clip,1+self.clip) * adv.detach()
            
            # combine surr_loss and entropy_loss as a_loss
            a_loss = -torch.min(surr1,surr2).mean() + entropy_loss
            self.recorder['a_loss'].append(a_loss.item())
            
            # update critic
            self.critic_optimizer.zero_grad()
            v_loss.backward()
            self.critic_optimizer.step()
            
            # update actor
            self.actor_optimizer.zero_grad()
            a_loss.backward()
            self.actor_optimizer.step()
        
        # sync actor_old and actor_new
        self.sync()
        self.replay_buffer.clear()
            
    def train(self, max_episodes=100,max_steps=1000, batch_size=1024):
        episode_rewards = []
        for episode in range(max_episodes):
            state = self.env.reset()
            episode_reward = 0
            for step in range(max_steps):
                action = self.get_action([state])
                next_state, reward, done, _ = self.env.step(action)
                self.replay_buffer.push(state, action, reward, next_state, done)
                episode_reward += reward
                
                # update agent
                if len(self.replay_buffer) >= batch_size:
                    self.update(batch_size)
                
                # if game over
                if done:
                    episode_rewards.append(episode_reward)
                    print("Episode " + str(episode) + ": " + str(episode_reward))
                    
                    # if sloved
                    if episode_rewards[-1] >= 200:
                        print('sloved!!! you get 200 score!')
                        return episode_rewards
                    
                    break
                
                state = next_state
        
        return episode_rewards

# %%
import gym

env = gym.make("LunarLander-v2")
env.seed(seed)

agent = PPOAgent(env)

history = agent.train(max_episodes=1000)
# Out:
# Episode 0: -218.77998657117857
# Episode 1: -103.78558329709332
# Episode 2: -349.95755567809715
# Episode 3: -120.54137631041505
# Episode 4: -94.19069747851968
# Episode 5: -106.57987475967602
# Episode 6: -108.5569819594576
# Episode 7: -140.42393686049715
# Episode 8: -488.8029323952689
# Episode 9: -145.05075141078567
# Episode 10: -215.0098509940275
# Episode 11: -196.69574357473
# Episode 12: 19.717286857895402
# Episode 13: -110.14806446336293
# Episode 14: -44.15892824001181
# Episode 15: -145.90415736343343
# Episode 16: -42.63152719649834
# Episode 17: -27.69464672285315
# Episode 18: -37.59519646829418
# Episode 19: -39.758177230521056
# Episode 20: -303.5403342921657
# Episode 21: -152.9738834935863
# Episode 22: -87.82530418026637
# Episode 23: -206.09449297970622
# Episode 24: -88.12181296578461
# Episode 25: -324.38364131664855
# Episode 26: -211.7846168110848
# Episode 27: -95.15884420868805
# Episode 28: -208.34858967238546
# Episode 29: -8.155593643572885
# Episode 30: -72.30152886586566
# Episode 31: -223.8630448952738
# Episode 32: -335.6475521741502
# Episode 33: -205.39784501217417
# Episode 34: -7.993136416040812
# Episode 35: -87.77223387685879
# Episode 36: -7.430047287242999
# Episode 37: -299.1870675860057
# Episode 38: -502.8519591432179
# Episode 39: 20.814707131032733
# Episode 40: -5.562963802275618
# Episode 41: -100.1717723870412
# Episode 42: 35.1955776889215
# Episode 43: -52.27149171723529
# Episode 44: -5.946810271615917
# Episode 45: -83.30999099427342
# Episode 46: -43.96922692067344
# Episode 47: -28.23305907457859
# Episode 48: -352.38608656224613
# Episode 49: -102.72182665133991
# Episode 50: 45.02695884843109
# Episode 51: -207.7799753588866
# Episode 52: -47.22087248521977
# Episode 53: -308.5986551659052
# Episode 54: 16.823004507601837
# Episode 55: -68.56043962453836
# Episode 56: -109.15868200627865
# Episode 57: 0.23909634632758525
# Episode 58: -194.2389166481074
# Episode 59: -106.59291359862952
# Episode 60: -137.97452868914684
# Episode 61: -80.25702014869705
# Episode 62: -240.07042104372198
# Episode 63: -15.337575115464631
# Episode 64: -169.97487085208377
# Episode 65: -11.43785166010332
# Episode 66: -93.24847966527906
# Episode 67: -36.12327439879958
# Episode 68: -343.3985581153455
# Episode 69: -170.76071930211128
# Episode 70: -35.286229735518035
# Episode 71: -19.688300101540037
# Episode 72: -17.333910146770236
# Episode 73: -46.077449504105076
# Episode 74: -99.31084526008554
# Episode 75: -53.09907145475103
# Episode 76: 5.121213667999996
# Episode 77: -30.6034578162257
# Episode 78: 259.84673129096205
# sloved!!! you get 200 score!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

plt.plot(history)
plt.plot(pd.Series(history).rolling(5).mean())
plt.show()

# %%
plt.plot(agent.recorder['v_loss'])

# %%
plt.plot(agent.recorder['a_loss'])

# %%
plt.plot(agent.recorder['e_loss'])

# %%
plt.plot(np.array(agent.recorder['ratio']).mean(axis=1))
